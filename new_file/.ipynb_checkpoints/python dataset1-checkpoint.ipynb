# %%
import pandas as pd

# %%
df=pd.read_csv("naukri_data_science_jobs_india.csv")

# %%
df
# Out:
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 11995                Tech Lead/Architect ( Contractual )
# 11996                               Tech Lead / POD Lead
# 11997     Java Full Stack Developer - Hibernate / Spring
# 11998                                  Tech Lead - Azure
# 11999            Full Stack Developer - Machine Learning
#
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job_Role            12000 non-null  object
#  1   Company             12000 non-null  object
#  2   Location            12000 non-null  object
#  3   Job Experience      12000 non-null  object
#  4   Skills/Description  12000 non-null  object
# dtypes: object(5)
# memory usage: 468.9+ KB

# %%
df["Job_Role"].value_counts()[120:130]
#Data Scientist Data Analyst Python Developer #Machine Learning Engineer #Sr. Data Scientist #Data Scientist 1
#Sr. Data Analyst #Principal Data Scientist #Data scientist #Junior Data Scientist #Data Scientist - Machine Learning
#Financial Analyst #Sr Data Scientist #Data Scientist: Advanced Analytics #AI Data Scientist #Data Science #DATA ANALYST
#Data Scientist (freelance)
# Out:
# Data Engineer - Java/Scala/Python                6
# DATA ANALYST                                     6
# Senior Machine Learning Engineer                 6
# Cloud Data Architecture Application Developer    6
# Data Warehouse Engineer                          6
# Team Lead/Consultant-Data Science                6
# Talend Big Data Application Developer            6
# Data engineer                                    6
# Data Engineer III                                6
# Data Scientist (freelance)                       6
# Name: Job_Role, dtype: int64

# %%
df_new=df[(df["Job_Role"]=="Data Scientist") |(df["Job_Role"]=="Data Analyst")|(df["Job_Role"]=="Python Developer")|(df["Job_Role"]=="Machine Learning Engineer")|(df["Job_Role"]==" Sr. Data Scientist")|(df["Job_Role"]=="Data Scientist 1")|(df["Job_Role"]=="Sr. Data Analyst")|(df["Job_Role"]=="Principal Data Scientist")|(df["Job_Role"]=="Junior Data Scientist")|(df["Job_Role"]=="Data Scientist - Machine Learning")|(df["Job_Role"]=="Financial Analyst")|(df["Job_Role"]=="Sr Data Scientist")|(df["Job_Role"]=="Data Scientist: Advanced Analytics")|(df["Job_Role"]=="AI Data Scientist")|(df["Job_Role"]=="Data Science")|(df["Job_Role"]=="Data Science")|(df["Job_Role"]=="DATA ANALYST")|(df["Job_Role"]=="Data Scientist (freelance)")]

# %%
df_new["Job_Role"].value_counts()
# Out:
# Data Scientist                        505
# Data Analyst                          353
# Python Developer                       42
# Machine Learning Engineer              24
# Principal Data Scientist               21
# Data Scientist 1                       14
# Sr. Data Analyst                       11
# Data Scientist - Machine Learning      10
# Junior Data Scientist                  10
# Financial Analyst                      10
# Sr Data Scientist                       8
# Data Scientist: Advanced Analytics      8
# AI Data Scientist                       8
# Data Science                            7
# Data Scientist (freelance)              6
# DATA ANALYST                            6
# Name: Job_Role, dtype: int64

# %%
df_new["Skills/Description"]
# Out:
# 3        python, machine learning, Data Science, data a...
# 4        IT Skills, Python, Data Science, Machine Learn...
# 5        Data Science, oral communication, Shell, Pytho...
# 6        Computer science, cassandra, Machine learning,...
# 8        Graphics, Bidding, Google Analytics, Data mana...
#                                ...
# 11886    IT Skills, Java, Python, Machine Learning, Art...
# 11893    C++, Agile, Keras, Python, TensorFlow, deep le...
# 11915    software engineering, machine learning, PyTorc...
# 11970    Python Data Analytics, Machine Learning, Data ...
# 11971    agile, data structures, comm, PyTorch, Spark, ...
# Name: Skills/Description, Length: 1043, dtype: object

# %%
count=0
for i in df['Skills/Description']:
    for j in i.split(","):
        if j =="Python":
            count=count+1
print(count)
# Out:
# 203

# %%
count=0
for i in df['Skills/Description']:
    for j in i.split(","):
        if j =="machine learning":
            count=count+1
print(count)
# Out:
# 31

# %%
lst_skills=[]
d={}
for i in df["Skills/Description"]:
    for j in i.split(","):
        lst_skills.append(j)

        
for i in list_skills:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
        
for w in sorted(d, key=d.get, reverse=True):
    print(w, d[w])
# Out:
#  Python 2508
#  IT Skills 1640
# IT Skills 1261
#  SQL 1253
#  Cloud 1206
#  Analytical 993
#  Big Data 990
#  Java 925
#  AWS 834
#  Machine Learning 826
#  Agile 756
# Computer science 738
#  Analytics 736
#  Data analysis 729
#  Machine learning 692
#  Spark 652
#  Consulting 649
#  Tableau 633
#  Testing 622
#  Azure 595
#  Data Science 590
#  Data management 535
#  Computer science 520
#  Hadoop 512
#  Coding 474
#  Oracle 412
#  Automation 410
#  Business intelligence 409
#  Javascript 407
#  ETL 389
#  Excel 388
#  Software Development 368
#  Artificial Intelligence 365
#  Data Analyst 362
#  MySQL 352
#  Data Analysis 352
#  Data modeling 352
#  communication 349
#  Data mining 346
#  Linux 330
#  Hive 326
#  R 325
#  Data Analytics 325
#  data science 322
#  Data quality 317
# Data Science 294
#  DevOps 292
#  HTML 284
#  Power BI 284
#  NoSQL 282
#  SAS 277
#  Data structures 274
#  Data collection 257
#  Operations 251
#  big data 249
#  analytical 249
#  Scala 240
# ...

# %%
lst_skills = []
d = {}

# Assuming df["Skills/Description"] contains the skills and descriptions
for i in df_new["Skills/Description"]:
    for j in i.split(","):
        lst_skills.append(j.lower())  # Convert to lowercase

for skill in lst_skills:
    if skill in d:
        d[skill] += 1
    else:
        d[skill] = 1

for w in sorted(d, key=d.get, reverse=True):
    print(w, d[w])
# Out:
#  machine learning 368
#  python 287
#  data analysis 180
#  data science 167
#  analytical 160
#  data mining 153
#  sql 151
#  data analyst 148
#  it skills 118
# it skills 111
# computer science 99
#  tableau 86
#  r 84
#  computer science 83
#  analytics 79
#  data visualization 70
# data analysis 69
# python 68
#  big data 68
# data science 63
#  java 62
#  data management 59
#  data collection 59
#  data analytics 58
#  excel 58
#  sas 57
#  data scientist 56
#  artificial intelligence 55
#  power bi 50
#  cloud 49
#  aws 47
#  deep learning 46
#  business intelligence 46
#  hadoop 42
#  predictive modeling 41
#  testing 39
#  data modeling 37
#  spark 35
#  forecasting 34
#  consulting 33
#  data structures 32
#  javascript 32
#  statistics 32
#  management 32
#  communication 31
#  agile 30
#  operations research 30
#  programming 30
#  azure 29
#  coding 29
#  algorithms 29
#  natural language processing 28
#  data quality 28
#  nlp 27
#  project management 26
# ...
