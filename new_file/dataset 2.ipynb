# %%
import pandas as pd

# %%
df=pd.read_csv("job_dataset.csv")

# %%
df
# Out:
#                                               job_title  \
# 0     Technology Lead : Data Science I Machine Learning
# 1                   Software Engineer, Machine Learning
# 2           Experienced Over The Shoulder Mechanic- C17
# 3                                        Data Scientist
# 4                                      Python Developer
# ...                                                 ...
# 1578        Learning Integration-Analyst/Senior Analyst
# 1579                                   Business Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# 1581  Program Research Analyst – Sustainable Cities ...
# 1582                                       Data Analyst
#
#                                              company  \
# 0                                    Infosys Limited
# 1                                             Google
# 2                                             BOEING
# 3                                    Infosys Limited
# ...

# %%
df["job_title"].value_counts()[80:90]
# Out:
# Senior Data Analyst - Data Engineering/Analytics          2
# Research Science Analyst _Global Banking Pool_Gurugram    2
# ESG Data Analyst                                          2
# Data Integrity - Analyst                                  2
# Senior Specialist - Data Science                          2
# Associate Test Engineer                                   2
# Data Engineer 1                                           2
# Computer Vision Specialist                                2
# Security Analyst                                          2
# Junior Business Analyst                                   2
# Name: job_title, dtype: int64

# %%
df_new=df[~(df["job_title"]=="Business Analyst") |(df["job_title"]=="Data Engineer")|(df["job_title"]=="Software Engineer")|(df["job_title"]=="Java Developer")|(df["job_title"]=="Full Stack Developer")|(df["job_title"]=="Quality Analyst")|(df["job_title"]=="Risk Analyst")|(df["job_title"]=="Customer Service Representative")|(df["job_title"]=="Research Analyst")|(df["job_title"]=="Operations Analyst")|(df["job_title"]=="Financial Analyst")|(df["job_title"]=="Data Operations Associate")|(df["job_title"]=="Data Management Analyst")|(df["job_title"]=="Roster for Data Unit Lead")|(df["job_title"]=="Technical Writer")|(df["job_title"]=="Software Engineer II")|(df["job_title"]=="QA Analyst")|(df["job_title"]=="VOIP Expert")|(df["job_title"]=="Data Engineer 1")]

# %%
df_new
# Out:
#                                               job_title  \
# 0     Technology Lead : Data Science I Machine Learning
# 1                   Software Engineer, Machine Learning
# 2           Experienced Over The Shoulder Mechanic- C17
# 3                                        Data Scientist
# 4                                      Python Developer
# ...                                                 ...
# 1577             Business Analyst-Business Intelligence
# 1578        Learning Integration-Analyst/Senior Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# 1581  Program Research Analyst – Sustainable Cities ...
# 1582                                       Data Analyst
#
#                                      company  \
# 0                            Infosys Limited
# 1                                     Google
# 2                                     BOEING
# 3                            Infosys Limited
# 4                            Infosys Limited
# ...

# %%
df_new=df_new.reset_index()

# %%
a=df_new["job_summary"][0]
print(a)
# Out:
# A day in the life of an Infoscion • As part of the Infosys delivery team, your primary role would be to interface with the client for quality assurance, issue…

# %%
print('Number of Rows: {}'.format(df_new.shape[0]))
print('Number of Columns: {}'.format(df_new.shape[1]))
# Out:
# Number of Rows: 1544
# Number of Columns: 9

# %%
df_new.shape
# Out:
# (1544, 9)

# %%
df_new["job_summary"][1]
# Out:
# '2 years of relevant work experience in machine learning software development and architectures for machine learning (with focus on deep learning).'

# %%
job_titles_to_exclude = ["Software Engineer", "Java Developer"]
df_filtered = df[~df["job_title"].isin(job_titles_to_exclude)]
df_filtered = df_filtered.reset_index(drop=True)
print(df_filtered.head())
# Out:
#                                            job_title          company  \
# 0  Technology Lead : Data Science I Machine Learning  Infosys Limited
# 1                Software Engineer, Machine Learning           Google
# 2        Experienced Over The Shoulder Mechanic- C17           BOEING
# 3                                     Data Scientist  Infosys Limited
# 4                                   Python Developer  Infosys Limited
#
#                              job_location  \
# 0                    Bengaluru, Karnataka
# 1                    Bengaluru, Karnataka
# 2  Remote in Air Force Station, Karnataka
# 3                    Bengaluru, Karnataka
# 4                    Bengaluru, Karnataka
#
#                                          job_summary  \
# 0  A day in the life of an Infoscion • As part of...
# 1  2 years of relevant work experience in machine...
# 2  This position will focus on supporting the Boe...
# 3  Anchor ML development track in a client projec...
# ...

# %%
df_new
# Out:
#       index                                          job_title  \
# 0         0  Technology Lead : Data Science I Machine Learning
# 1         1                Software Engineer, Machine Learning
# 2         2        Experienced Over The Shoulder Mechanic- C17
# 3         3                                     Data Scientist
# 4         4                                   Python Developer
# ...     ...                                                ...
# 1539   1577             Business Analyst-Business Intelligence
# 1540   1578        Learning Integration-Analyst/Senior Analyst
# 1541   1580         Research Analyst - Central Events (Hybrid)
# 1542   1581  Program Research Analyst – Sustainable Cities ...
# 1543   1582                                       Data Analyst
#
#                                      company  \
# 0                            Infosys Limited
# 1                                     Google
# 2                                     BOEING
# ...

# %%
df_new["job_title"].value_counts()[0:20]
# Out:
# Data Analyst                   200
# Data Scientist                  57
# Machine Learning Engineer       32
# Data Engineer                   25
# Computer Vision Engineer        19
# Senior Data Analyst             17
# Data Science Trainer            10
# Data Science                     8
# Data science                     8
# Sr. Data Analyst                 6
# Data Science/Data Analytics      6
# Software Engineer                6
# Java Developer                   5
# Power BI Developer               5
# ML Engineer                      5
# Data Science Engineer            5
# Data Analytics                   5
# Data Analyst Intern              4
# Full Stack Developer             4
# Quality Analyst                  4
# Name: job_title, dtype: int64
